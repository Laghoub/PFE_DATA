# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA
from pandas.plotting import register_matplotlib_converters

# %%
nbpres = pd.read_excel("TimeSeries/dataset.xlsx")
#nbpres = nbpres[: 30]
nbpres
# Out:
#            date  presence
# 0    2019-09-01       153
# 1    2019-09-02       151
# 2    2019-09-03       103
# 3    2019-09-04        87
# 4    2019-09-05       170
# ...         ...       ...
# 1075 2022-08-11       169
# 1076 2022-08-12         0
# 1077 2022-08-13        83
# 1078 2022-08-14       152
# 1079 2022-08-15       149
#
# [1080 rows x 2 columns]

# %%
nbpres.drop(nbpres[nbpres.presence==0].index, inplace=True)

# %%
nbpres
# Out:
#            date  presence
# 0    2019-09-01       153
# 1    2019-09-02       151
# 2    2019-09-03       103
# 3    2019-09-04        87
# 4    2019-09-05       170
# ...         ...       ...
# 1074 2022-08-10        82
# 1075 2022-08-11       169
# 1077 2022-08-13        83
# 1078 2022-08-14       152
# 1079 2022-08-15       149
#
# [818 rows x 2 columns]

# %%
nbpres.describe()
# Out:
#          presence       notrend       trend    forecast
# count  818.000000  8.180000e+02  818.000000  818.000000
# mean   138.353301  1.645541e-13  138.353301  138.135445
# std     32.151319  3.210359e+01    1.751292   23.387933
# min     79.000000 -6.212906e+01  135.325533   82.076693
# 25%    105.000000 -3.311026e+01  136.839417  115.969196
# 50%    150.000000  1.151328e+01  138.353301  143.701146
# 75%    153.000000  1.577285e+01  139.867185  155.864455
# max    184.000000  4.643668e+01  141.381069  193.350268

# %%
nbpres['presence'].plot()
# Out:
# <AxesSubplot:>

# %%
nbpres['date'] = pd.to_datetime(nbpres['date'],infer_datetime_format=True) #convert from string to datetime
indexedDataset = nbpres.set_index(['date'])

# %%
plt.xlabel('Date')
plt.ylabel("nombre d'étudiants présents")
plt.plot(indexedDataset.presence)

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decompose_data = seasonal_decompose(indexedDataset[:30], model="additive",extrapolate_trend='freq', period=7)
decompose_data.plot();

# %%
seasonality=decompose_data.seasonal
plt.xlabel('Date')
plt.ylabel("saisonalité")
seasonality.plot(color='green')
# Out:
# <AxesSubplot:xlabel='date', ylabel='saisonalité'>

# %%
from statsmodels.tsa.tsatools import detrend
notrend = detrend(nbpres['presence'])
nbpres["notrend"] = notrend
nbpres["trend"] = nbpres['presence'] - notrend
nbpres.tail()
# Out:
#            date  presence    notrend       trend
# 1074 2022-08-10        82 -53.355180  135.355180
# 1075 2022-08-11       169  33.652232  135.347768
# 1077 2022-08-13        83 -52.340356  135.340356
# 1078 2022-08-14       152  16.667055  135.332945
# 1079 2022-08-15       149  13.674467  135.325533

# %%
nbpres.plot(y=["presence", "trend"], figsize=(14,4));

# %%
from statsmodels.tsa.stattools import adfuller
dftest = adfuller(indexedDataset.presence, autolag = 'AIC')
print("1. ADF : ",dftest[0])
print("2. P-Value : ", dftest[1])
print("3. Num Of Lags : ", dftest[2])
print("4. Num Of Observations Used For ADF Regression and Critical Values Calculation :", dftest[3])
print("5. Critical Values :")
for key, val in dftest[4].items():
    print("\t",key, ": ", val)
# Out:
# 1. ADF :  -2.452914428995365
# 2. P-Value :  0.1273549619603146
# 3. Num Of Lags :  17
# 4. Num Of Observations Used For ADF Regression and Critical Values Calculation : 800
# 5. Critical Values :
# 	 1% :  -3.438550508267578
# 	 5% :  -2.8651595688281253
# 	 10% :  -2.5686973890625

# %%
rolmean = nbpres.rolling(window=7).mean() #window size 12 denotes 12 months, giving rolling mean at yearly level
rolstd = nbpres.rolling(window=7).std()
print(rolmean,rolstd)
# Out:
#         presence
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 1074  110.285714
# 1075  119.571429
# 1077  119.714286
# 1078  117.285714
# 1079  127.000000
#
# [818 rows x 1 columns]        presence
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 1074  36.426704
# 1075  42.359010
# 1077  42.212614
# 1078  39.292554
# 1079  37.175261
#
# [818 rows x 1 columns]

# %%
#Plot rolling statistics
plt.figure(figsize=(15,7))
orig = plt.plot(nbpres.presence, color='blue', label='Original')
mean = plt.plot(rolmean, color='red', label='Rolling Mean')
std = plt.plot(rolstd, color='black', label='Rolling Std')
plt.legend(loc='best')
plt.title('Rolling Mean & Standard Deviation')
plt.show(block=False)

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plt.rcParams.update({'figure.figsize':(9,7), 'figure.dpi':120})


# Original Series
fig, axes = plt.subplots(3, 2, sharex=False)
axes[0, 0].plot(nbpres.presence); axes[0, 0].set_title('Original Series')
plot_acf(nbpres.presence, ax=axes[0, 1])

# 1st Differencing
axes[1, 0].plot(nbpres.presence.diff()); axes[1, 0].set_title('1st Order Differencing')
plot_acf(nbpres.presence.diff().dropna(), ax=axes[1, 1])

# 2nd Differencing
axes[2, 0].plot(nbpres.presence.diff().diff()); axes[2, 0].set_title('2nd Order Differencing')
plot_acf(nbpres.presence.diff().diff().dropna(), ax=axes[2, 1])

plt.show()
plt.savefig("acf.png")

# %%
# PACF plot of 1st differenced series
plt.rcParams.update({'figure.figsize':(9,3), 'figure.dpi':120})

fig, axes = plt.subplots(1, 2, sharex=False)
#axes[0].plot(indexedDataset.presence); axes[0].set_title('jeu de données')
plot_pacf(indexedDataset.presence.dropna(), ax=axes[1])

plt.show()

# %%
residuals = pd.DataFrame(model_fit.resid)
fig, ax = plt.subplots(1,2)
residuals.plot(title="Residuals", ax=ax[0])
residuals.plot(kind='kde', title='Density', ax=ax[1])
plt.show()

# %%
train = indexedDataset.presence[:497]
test = indexedDataset.presence[497:]

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
model=ARIMA(nbpres['presence'],order=(7,0,1))
model_fit = model.fit(disp=0)
# Out:
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'

# %%
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:               presence   No. Observations:                  818
# Model:                     ARMA(7, 1)   Log Likelihood               -3692.129
# Method:                       css-mle   S.D. of innovations             22.028
# Date:                Sun, 07 Aug 2022   AIC                           7404.258
# Time:                        23:18:52   BIC                           7451.327
# Sample:                             0   HQIC                          7422.321
#
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const            136.3770      4.136     32.975      0.000     128.271     144.483
# ar.L1.presence     0.5129      0.054      9.514      0.000       0.407       0.619
# ar.L2.presence     0.1904      0.032      5.897      0.000       0.127       0.254
# ar.L3.presence     0.1482      0.031      4.750      0.000       0.087       0.209
# ar.L4.presence    -0.0308      0.032     -0.969      0.332      -0.093       0.032
# ar.L5.presence    -0.0007      0.032     -0.021      0.983      -0.063       0.061
# ar.L6.presence     0.5738      0.031     18.446      0.000       0.513       0.635
# ar.L7.presence    -0.4172      0.046     -8.986      0.000      -0.508      -0.326
# ma.L1.presence    -0.8682      0.038    -22.854      0.000      -0.943      -0.794
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.0725           -0.0000j            1.0725           -0.5000
# AR.2           -0.5592           -0.8921j            1.0529           -0.3391
# AR.3           -0.5592           +0.8921j            1.0529            0.3391
# AR.4            0.5317           -1.0262j            1.1557           -0.1739
# AR.5            0.5317           +1.0262j            1.1557            0.1739
# AR.6            1.0134           -0.0000j            1.0134           -0.0000
# AR.7            1.4895           -0.0000j            1.4895           -0.0000
# MA.1            1.1518           +0.0000j            1.1518            0.0000
# -----------------------------------------------------------------------------
# """

# %%
nbpres['forecast']=model_fit.predict(exog=None,dynamic=False)
nbpres[['presence','forecast']].plot(figsize=(12,8))
# Out:
# <AxesSubplot:>

# %%
import statsmodels.api as sm
model=sm.tsa.statespace.SARIMAX(nbpres['presence'],order=(7, 0, 6),seasonal_order=(7,0,6,12))
results=model.fit()
# Out:
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
nbpres['forecast']=results.predict(exog=None,dynamic=False)
nbpres[['presence','forecast']].plot(figsize=(12,8))
# Out:
# <AxesSubplot:>

# %%
from statsmodels.tsa.arima_model import ARIMA

import pmdarima as pm

model = pm.auto_arima(nbpres.presence, start_p=1, start_q=1,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=15, max_q=6, # maximum p and q
                      m=1,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=1,
                      start_Q=1,
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)

print(model_fit.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=7988.211, Time=1.01 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=10431.525, Time=0.08 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=8773.268, Time=0.12 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=9825.495, Time=0.27 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=7826.506, Time=0.90 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=8388.091, Time=0.14 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=7729.118, Time=0.57 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=inf, Time=0.11 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=7836.647, Time=0.86 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=7731.014, Time=1.29 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=7739.139, Time=0.56 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=inf, Time=0.31 sec
#  ARIMA(4,0,2)(0,0,0)[0]             : AIC=7672.070, Time=0.95 sec
#  ARIMA(5,0,2)(0,0,0)[0]             : AIC=7644.015, Time=1.15 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=7838.639, Time=0.87 sec
#  ARIMA(6,0,2)(0,0,0)[0]             : AIC=7432.181, Time=0.82 sec
#  ARIMA(6,0,1)(0,0,0)[0]             : AIC=7432.148, Time=1.08 sec
#  ARIMA(6,0,0)(0,0,0)[0]             : AIC=inf, Time=0.65 sec
#  ARIMA(7,0,1)(0,0,0)[0]             : AIC=7412.950, Time=1.54 sec
#  ARIMA(7,0,0)(0,0,0)[0]             : AIC=inf, Time=0.68 sec
#  ARIMA(8,0,1)(0,0,0)[0]             : AIC=7435.703, Time=1.66 sec
#  ARIMA(7,0,2)(0,0,0)[0]             : AIC=7417.844, Time=1.69 sec
#  ARIMA(8,0,0)(0,0,0)[0]             : AIC=inf, Time=0.63 sec
#  ARIMA(8,0,2)(0,0,0)[0]             : AIC=7415.367, Time=1.87 sec
#  ARIMA(7,0,1)(0,0,0)[0] intercept   : AIC=7415.600, Time=1.66 sec
#
# Best model:  ARIMA(7,0,1)(0,0,0)[0]
# Total fit time: 21.935 seconds
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:               presence   No. Observations:                  818
# Model:                     ARMA(7, 6)   Log Likelihood               -3671.340
# Method:                       css-mle   S.D. of innovations             21.468
# Date:                Sun, 07 Aug 2022   AIC                           7372.680
# Time:                        23:16:47   BIC                           7443.283
# Sample:                             0   HQIC                          7399.774
#
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const            136.2737      4.258     32.007      0.000     127.929     144.619
# ar.L1.presence     0.1314      0.212      0.619      0.536      -0.284       0.547
# ar.L2.presence     0.0177      0.034      0.521      0.602      -0.049       0.084
# ar.L3.presence     0.0026      0.032      0.080      0.936      -0.061       0.066
# ar.L4.presence    -0.0078      0.033     -0.239      0.811      -0.072       0.056
# ar.L5.presence     0.1418      0.035      4.103      0.000       0.074       0.210
# ar.L6.presence     0.7695      0.053     14.552      0.000       0.666       0.873
# ar.L7.presence    -0.1144      0.156     -0.733      0.464      -0.420       0.192
# ma.L1.presence    -0.5346      0.210     -2.540      0.011      -0.947      -0.122
# ma.L2.presence     0.1104      0.100      1.109      0.267      -0.085       0.306
# ma.L3.presence     0.1459      0.058      2.512      0.012       0.032       0.260
# ma.L4.presence    -0.0506      0.063     -0.803      0.422      -0.174       0.073
# ma.L5.presence    -0.1531      0.061     -2.506      0.012      -0.273      -0.033
# ma.L6.presence    -0.1630      0.082     -1.982      0.048      -0.324      -0.002
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.0691           -0.0000j            1.0691           -0.5000
# AR.2           -0.5550           -0.8943j            1.0525           -0.3384
# AR.3           -0.5550           +0.8943j            1.0525            0.3384
# AR.4            0.4943           -0.9009j            1.0276           -0.1701
# AR.5            0.4943           +0.9009j            1.0276            0.1701
# AR.6            1.0123           -0.0000j            1.0123           -0.0000
# AR.7            6.9059           -0.0000j            6.9059           -0.0000
# MA.1            1.1438           -0.0000j            1.1438           -0.0000
# MA.2            0.5887           -0.9683j            1.1332           -0.1631
# MA.3            0.5887           +0.9683j            1.1332            0.1631
# MA.4           -1.6122           -0.0000j            1.6122           -0.5000
# MA.5           -0.8239           -1.3824j            1.6093           -0.3355
# MA.6           -0.8239           +1.3824j            1.6093            0.3355
# -----------------------------------------------------------------------------

# %%
import time
start_time = time.perf_counter()
model=ARIMA(nbpres['presence'],order=(7,0,1))
model_fit = model.fit(disp=0)
end_time = time.perf_counter()
print("temps d'éxécution", end_time - start_time)
# Out:
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# temps d'éxécution 2.487640499995905

# %%
start_time = time.perf_counter()
nbpres['forecast']=model_fit.predict(exog=None,dynamic=False)
nbpres[['presence','forecast']].plot(figsize=(12,8))
end_time = time.perf_counter()
print("temps d'éxécution", end_time - start_time)
# Out:
# temps d'éxécution 0.10930850000295322

# %%
import statsmodels.api as sm
start_time = time.perf_counter()
model=sm.tsa.statespace.SARIMAX(nbpres['presence'],order=(7, 0, 1),seasonal_order=(2,0,6,12))
results=model.fit()
end_time = time.perf_counter()
print("temps d'éxécution", end_time - start_time)
# Out:
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# temps d'éxécution 111.08487869999954

# %%
nbpres['forecast']=results.predict(exog=None,dynamic=False)
nbpres[['presence','forecast']].plot(figsize=(12,8))

# %%
nbpres['forecast'][545:]

# %%
nbpres['date'][545:]

# %%
train = indexedDataset.presence[:545]
test = indexedDataset.presence[545:]

# %%
import statsmodels.api as sm
model=sm.tsa.statespace.SARIMAX(train,order=(7, 0, 1),seasonal_order=(7,0,1,12))
results=model.fit()

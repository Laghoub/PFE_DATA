# %% [markdown]
# # Extration des données météorologiques

# %% [markdown]
# ## Dans un prmier temps nous installons les modules necessaires

# %%
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# * bs4: Beautiful Soup est une bibliothèque qui permet de récupérer facilement les informations des pages Web. Qu’il s’agisse d’une page HTML ou XML, qui peut ensuite être utilisée pour itérer, rechercher et modifier les données qu’elle contient.

# %%
import requests
from bs4 import BeautifulSoup as btf
from random import choices
import pandas as pd
import random
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix 
import lightgbm as lgb

# %%
pip install lightgbm
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# il faut maintenant utiliser ces deux modules pour extraire les données

# %%
city = "Algiers"

url = "https://www.google.com/search?q="+"weather"+city
  
html = requests.get(url).content 
  
soup = BeautifulSoup(html, 'html.parser')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-b2ce41218599> in <module>
#       1 city = "Algiers"
#       2
# ----> 3 url = "https://www.google.com/search?q="+"weather"+city+date
#       4
#       5 html = requests.get(url).content
#
# NameError: name 'date' is not defined

# %%
temp = soup.find('div', attrs={'class': 'BNeawe iBp4i AP7Wnd'}).text 
  
str = soup.find('div', attrs={'class': 'BNeawe tAd8D AP7Wnd'}).text 
data = str.split('\n') 
time = data[0] 
sky = data[1]

# %%
print(sky)

# %%
Type = ['Ensoleillé' , 'Nuageux' , 'Pluvieux']
weightsSep = [0.75,0.25,0]
weightsOct = [0.25,0.75,0]
weightsNov = [0.2,0.8,0.2]
weightshiv = [0,0.3,0.7]
weightsmars = [0.1,0.2,0.7]
weightsAvr = [0.25,0.4,0.35]
weightsmai = [0.5,0.4,0.1]
weightsete = [0.95,0.05,0]

# %%
ListDate = []

# %%
import datetime
for i in range(1080):
    date = datetime.datetime(2019,9,1,12,4,5) + datetime.timedelta(days=i)
    dateStr = date.strftime("%d-%m-%Y")
    ListDate.append(dateStr)    

ListDate
# Out:
# ['01-09-2019',
#  '02-09-2019',
#  '03-09-2019',
#  '04-09-2019',
#  '05-09-2019',
#  '06-09-2019',
#  '07-09-2019',
#  '08-09-2019',
#  '09-09-2019',
#  '10-09-2019',
#  '11-09-2019',
#  '12-09-2019',
#  '13-09-2019',
#  '14-09-2019',
#  '15-09-2019',
#  '16-09-2019',
#  '17-09-2019',
#  '18-09-2019',
#  '19-09-2019',
#  '20-09-2019',
#  '21-09-2019',
#  '22-09-2019',
#  '23-09-2019',
#  '24-09-2019',
#  '25-09-2019',
#  '26-09-2019',
#  '27-09-2019',
#  '28-09-2019',
#  '29-09-2019',
#  '30-09-2019',
#  '01-10-2019',
#  '02-10-2019',
#  '03-10-2019',
#  '04-10-2019',
#  '05-10-2019',
#  '06-10-2019',
#  '07-10-2019',
#  '08-10-2019',
#  '09-10-2019',
#  '10-10-2019',
#  '11-10-2019',
#  '12-10-2019',
#  '13-10-2019',
#  '14-10-2019',
#  '15-10-2019',
#  '16-10-2019',
#  '17-10-2019',
#  '18-10-2019',
#  '19-10-2019',
#  '20-10-2019',
#  '21-10-2019',
#  '22-10-2019',
#  '23-10-2019',
#  '24-10-2019',
#  '25-10-2019',
#  '26-10-2019',
#  '27-10-2019',
#  '28-10-2019',
# ...

# %%
for j in range(30):
    choix = choices(Type,weightsSep)[0]
    meteo.append(choix)

# %%
for j in range(30):
    choix = choices(Type,weightsOct)[0]
    meteo.append(choix)

# %%
for j in range(30):
    choix = choices(Type,weightsNov)[0]
    meteo.append(choix)

# %%
for j in range(90):
    choix = choices(Type,weightshiv)[0]
    meteo.append(choix)

# %%
for j in range(30):
    choix = choices(Type,weightsmars)[0]
    meteo.append(choix)

# %%
for j in range(30):
    choix = choices(Type,weightsAvr)[0]
    meteo.append(choix)

# %%
for j in range(30):
    choix = choices(Type,weightsmai)[0]
    meteo.append(choix)

# %%
for j in range(90):
    choix = choices(Type,weightsete)[0]
    meteo.append(choix)

# %%
len(meteo)

# %%
len(ListDate)

# %%
datameteo = {
  "date": ListDate,
  "meteo": meteo
}
df_meteo = pd.DataFrame(datameteo)

# %%
df

# %%
df.to_excel("datameteo.xlsx")

# %%
dataevent = pd.read_excel("event.xlsx")
dataevent
# Out:
#       Unnamed: 0        date    Event
# 0              0  01-09-2019   Normal
# 1              1  02-09-2019   Normal
# 2              2  03-09-2019   Normal
# 3              3  04-09-2019   Normal
# 4              4  05-09-2019   Normal
# ...          ...         ...      ...
# 1075        1075  11-08-2022   Normal
# 1076        1076  12-08-2022  Weekend
# 1077        1077  13-08-2022   Normal
# 1078        1078  14-08-2022   Normal
# 1079        1079  15-08-2022   Normal
#
# [1080 rows x 3 columns]

# %%
donnees = pd.read_excel("menu.xlsx")
donnees

# %%
salaire = [random.randrange(18000,25000), random.randrange(25000,40000) , random.randrange(40000,50000), random.randrange(50000,60000),
           random.randrange(60000,80000),random.randrange(80000,100000), random.randrange(100000,120000), 
          random.randrange(120000,150000), random.randrange(150000,200000)]
poids = [0.20,0.15,0.2,0.15,0.1,0.06,0.06,0.05,0.03]
moyDesRev = []

# %% [markdown]
# # génération de la colonne moyenne des revenus

# %%
for i in range (200):
    moyDesRev.append(choices(salaire,poids)[0])

# %%
moyDesRev

# %% [markdown]
# # La colonne hebergement

# %%
hebergTypes = ['interne' , 'externe']
poidsHeb = [0.3 , 0.7]
listHeb = []

# %%
for i in range(200):
    listHeb.append(choices(hebergTypes,poidsHeb)[0])

# %%
listHeb
# Out:
# ['interne',
#  'externe',
#  'externe',
#  'externe',
#  'interne',
#  'externe',
#  'interne',
#  'externe',
#  'externe',
#  'externe',
#  'interne',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'interne',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'interne',
#  'externe',
#  'interne',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'interne',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'interne',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'interne',
#  'interne',
#  'externe',
#  'externe',
#  'interne',
#  'interne',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'interne',
#  'externe',
#  'externe',
#  'externe',
#  'externe',
#  'interne',
# ...

# %%
population = {
  "Heberg": listHeb,
  "Rev_par": moyDesRev
}
pop = pd.DataFrame(population)

# %%
pop
# Out:
#       Heberg  Rev_par
# 0    interne    56879
# 1    externe    19184
# 2    externe    56879
# 3    externe    19184
# 4    interne   139936
# ..       ...      ...
# 195  interne    25251
# 196  interne    19184
# 197  interne    56879
# 198  interne    56879
# 199  externe    46901
#
# [200 rows x 2 columns]

# %%
pop.to_excel("etudiants.xlsx")

# %% [markdown]
# # La table population

# %%
df_population = pd.read_excel("etudiants.xlsx")
df_population
# Out:
#     idEtudiant   Heberg  Rev_par Bourse idRestaurant
# 0      17/0001  interne    56879    Oui       Esi016
# 1      17/0002  externe    19184    Oui       Esi016
# 2      17/0003  externe    56879    Oui       Esi016
# 3      17/0004  externe    19184    Oui       Esi016
# 4      17/0005  interne   139936    Non       Esi016
# ..         ...      ...      ...    ...          ...
# 195    17/0196  interne    25251    Oui       Esi016
# 196    17/0197  interne    19184    Oui       Esi016
# 197    17/0198  interne    56879    Oui       Esi016
# 198    17/0199  interne    56879    Oui       Esi016
# 199    17/0200  externe    46901    Oui       Esi016
#
# [200 rows x 5 columns]

# %%
df_event= pd.read_excel("event.xlsx")
df_event
# Out:
#       Unnamed: 0        date    Event
# 0              0  01-09-2019   Normal
# 1              1  02-09-2019   Normal
# 2              2  03-09-2019   Normal
# 3              3  04-09-2019   Normal
# 4              4  05-09-2019   Normal
# ...          ...         ...      ...
# 1075        1075  11-08-2022   Normal
# 1076        1076  12-08-2022  Weekend
# 1077        1077  13-08-2022   Normal
# 1078        1078  14-08-2022   Normal
# 1079        1079  15-08-2022   Normal
#
# [1080 rows x 3 columns]

# %%
df_meteo = pd.read_excel("meteo.xlsx")
df_meteo
# Out:
#       Unnamed: 0        date       meteo
# 0              0  01-09-2019  Ensoleillé
# 1              1  02-09-2019  Ensoleillé
# 2              2  03-09-2019  Ensoleillé
# 3              3  04-09-2019  Ensoleillé
# 4              4  05-09-2019  Ensoleillé
# ...          ...         ...         ...
# 1075        1075  11-08-2022  Ensoleillé
# 1076        1076  12-08-2022  Ensoleillé
# 1077        1077  13-08-2022  Ensoleillé
# 1078        1078  14-08-2022  Ensoleillé
# 1079        1079  15-08-2022  Ensoleillé
#
# [1080 rows x 3 columns]

# %%
df_menu=pd.read_excel("menu.xlsx")

# %%
df_menu_Esi=df_menu.loc[df_menu['idRestaurant'] == "Esi016"]
df_menu_Esi
# Out:
#      idRestaurant        date  Type       Plat
# 0          Esi016  01-09-2019  midi  Lentilles
# 1          Esi016  02-09-2019  midi     Loubia
# 2          Esi016  03-09-2019  midi        Riz
# 3          Esi016  04-09-2019  midi  Spaghetti
# 4          Esi016  05-09-2019  midi   Couscous
# ...           ...         ...   ...        ...
# 1075       Esi016  11-08-2022  midi   Couscous
# 1076       Esi016  12-08-2022  midi    Weekend
# 1077       Esi016  13-08-2022  midi    Weekend
# 1078       Esi016  14-08-2022  midi  Lentilles
# 1079       Esi016  15-08-2022  midi     Loubia
#
# [1080 rows x 4 columns]

# %%
result = pd.merge(df_menu_Esi,df_meteo, on="date")
result2 = pd.merge(result,df_event, on="date")

# %%
result2
# Out:
#      idRestaurant        date  Type       Plat  Unnamed: 0_x       meteo  \
# 0          Esi016  01-09-2019  midi  Lentilles             0  Ensoleillé
# 1          Esi016  02-09-2019  midi     Loubia             1  Ensoleillé
# 2          Esi016  03-09-2019  midi        Riz             2  Ensoleillé
# 3          Esi016  04-09-2019  midi  Spaghetti             3  Ensoleillé
# 4          Esi016  05-09-2019  midi   Couscous             4  Ensoleillé
# ...           ...         ...   ...        ...           ...         ...
# 1075       Esi016  11-08-2022  midi   Couscous          1075  Ensoleillé
# 1076       Esi016  12-08-2022  midi    Weekend          1076  Ensoleillé
# 1077       Esi016  13-08-2022  midi    Weekend          1077  Ensoleillé
# 1078       Esi016  14-08-2022  midi  Lentilles          1078  Ensoleillé
# 1079       Esi016  15-08-2022  midi     Loubia          1079  Ensoleillé
#
#       Unnamed: 0_y    Event
# 0                0   Normal
# 1                1   Normal
# ...

# %%
resultf = result2.drop(columns=["Unnamed: 0_x","Unnamed: 0_y"], axis=1)

# %%
resultf
# Out:
#      idRestaurant        date  Type       Plat       meteo    Event
# 0          Esi016  01-09-2019  midi  Lentilles  Ensoleillé   Normal
# 1          Esi016  02-09-2019  midi     Loubia  Ensoleillé   Normal
# 2          Esi016  03-09-2019  midi        Riz  Ensoleillé   Normal
# 3          Esi016  04-09-2019  midi  Spaghetti  Ensoleillé   Normal
# 4          Esi016  05-09-2019  midi   Couscous  Ensoleillé   Normal
# ...           ...         ...   ...        ...         ...      ...
# 1075       Esi016  11-08-2022  midi   Couscous  Ensoleillé   Normal
# 1076       Esi016  12-08-2022  midi    Weekend  Ensoleillé  Weekend
# 1077       Esi016  13-08-2022  midi    Weekend  Ensoleillé   Normal
# 1078       Esi016  14-08-2022  midi  Lentilles  Ensoleillé   Normal
# 1079       Esi016  15-08-2022  midi     Loubia  Ensoleillé   Normal
#
# [1080 rows x 6 columns]

# %%
df_pop = pd.read_excel("etudiants.xlsx")
df_pop
# Out:
#     idEtudiant   Heberg  Rev_par Bourse idRestaurant
# 0      17/0001  interne    56879    Oui       Esi016
# 1      17/0002  externe    19184    Oui       Esi016
# 2      17/0003  externe    56879    Oui       Esi016
# 3      17/0004  externe    19184    Oui       Esi016
# 4      17/0005  interne   139936    Non       Esi016
# ..         ...      ...      ...    ...          ...
# 195    17/0196  interne    25251    Oui       Esi016
# 196    17/0197  interne    19184    Oui       Esi016
# 197    17/0198  interne    56879    Oui       Esi016
# 198    17/0199  interne    56879    Oui       Esi016
# 199    17/0200  externe    46901    Oui       Esi016
#
# [200 rows x 5 columns]

# %%
resultMerge = pd.merge(resultf,df_pop, on="idRestaurant")
resultMerge
# Out:
#        idRestaurant        date  Type       Plat       meteo   Event  \
# 0            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 1            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 2            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 3            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 4            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# ...             ...         ...   ...        ...         ...     ...
# 215995       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215996       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215997       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215998       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215999       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
#
#        idEtudiant   Heberg  Rev_par Bourse
# 0         17/0001  interne    56879    Oui
# 1         17/0002  externe    19184    Oui
# ...

# %%
resultMerge.to_csv("dataset.csv")

# %%
table = pd.read_csv("dataset.csv")
table
# Out:
#         Unnamed: 0 idRestaurant        date  Type       Plat       meteo  \
# 0                0       Esi016  01-09-2019  midi  Lentilles  Ensoleillé
# 1                1       Esi016  01-09-2019  midi  Lentilles  Ensoleillé
# 2                2       Esi016  01-09-2019  midi  Lentilles  Ensoleillé
# 3                3       Esi016  01-09-2019  midi  Lentilles  Ensoleillé
# 4                4       Esi016  01-09-2019  midi  Lentilles  Ensoleillé
# ...            ...          ...         ...   ...        ...         ...
# 215995      215995       Esi016  15-08-2022  midi     Loubia  Ensoleillé
# 215996      215996       Esi016  15-08-2022  midi     Loubia  Ensoleillé
# 215997      215997       Esi016  15-08-2022  midi     Loubia  Ensoleillé
# 215998      215998       Esi016  15-08-2022  midi     Loubia  Ensoleillé
# 215999      215999       Esi016  15-08-2022  midi     Loubia  Ensoleillé
#
#          Event idEtudiant   Heberg  Rev_par Bourse
# ...

# %%
table2 = table.drop(columns=['Unnamed: 0'], axis=1)
table2
# Out:
#        idRestaurant        date  Type       Plat       meteo   Event  \
# 0            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 1            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 2            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 3            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 4            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# ...             ...         ...   ...        ...         ...     ...
# 215995       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215996       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215997       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215998       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215999       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
#
#        idEtudiant   Heberg  Rev_par Bourse
# 0         17/0001  interne    56879    Oui
# 1         17/0002  externe    19184    Oui
# ...

# %% [markdown]
# # Probabilité selon le plat

# %%
def probPlat(plat):
    if (plat=="Lentilles"):
        return 0.1
    if (plat=="Loubia"):
        return 0.12
    if (plat=="Riz"):
        return 0.4*0.2
    if (plat=="Spaghetti"):
        return 0.3*0.2
    if (plat=="Couscous"):
        return 0.9*0.2
    else: return 0

# %%
probPlat("Couscous")
# Out:
# 0.18000000000000002

# %% [markdown]
# # Probabilité selon la météo

# %%
def probMeteo(meteo):
    if (meteo=="Ensoleillé"):
        return 0.02
    if (meteo=="Nuageux"):
        return 0.06
    if (meteo=="Mauvais"):
        return 0.09

# %% [markdown]
# # Probabilité selon la bourse

# %%
def probBourse(bourse):
    if(bourse=="Oui"):
        return 0.7*0.1
    if(bourse=="Non"):
        return 0.6*0.1

# %% [markdown]
# # Probabilité selon l'hébergement

# %%
def probHeberg(heberg):
    if(heberg=="externe"):
        return 0.3*0.8
    if(heberg=="interne"):
        return 0.3*0.5

# %% [markdown]
# # probabilité selon les revenues des parents

# %%
def probRevenues(revenu):
    if(revenu<50000):
        return 0.9*0.35
    if(revenu>50000 and revenu<100000):
        return 0.6*0.35
    if (revenu>100000 and revenu<150000):
        return 0.3*0.35
    if (revenu>150000):
        return 0.05*0.35

# %% [markdown]
# # probabilité selon les evenements

# %%
def probEvent(event):
    if(event=="Normal"):
        return 1
    return 0

# %%
probEvent("Normal")
# Out:
# 1

# %%
table3 = table2.assign(presence=0.001)

# %%
table3
# Out:
#        idRestaurant        date  Type       Plat       meteo   Event  \
# 0            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 1            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 2            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 3            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 4            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# ...             ...         ...   ...        ...         ...     ...
# 215995       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215996       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215997       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215998       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215999       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
#
#        idEtudiant   Heberg  Rev_par Bourse  presence
# 0         17/0001  interne    56879    Oui     0.001
# ...

# %%
for i in range(216000):
    table3["presence"][i] =(probPlat(table3["Plat"][i])+probMeteo(table3["meteo"][i])+probBourse(table3["Bourse"][i])+probHeberg(table3["Heberg"][i])+probRevenues(table3["Rev_par"][i]))*probEvent(table3["Event"][i])
# Out:
# <ipython-input-15-c168420c2611>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   table3["presence"][i] =(probPlat(table3["Plat"][i])+probMeteo(table3["meteo"][i])+probBourse(table3["Bourse"][i])+probHeberg(table3["Heberg"][i])+probRevenues(table3["Rev_par"][i]))*probEvent(table3["Event"][i])

# %%
table3
# Out:
#        idRestaurant        date  Type       Plat       meteo   Event  \
# 0            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 1            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 2            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 3            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 4            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# ...             ...         ...   ...        ...         ...     ...
# 215995       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215996       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215997       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215998       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215999       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
#
#        idEtudiant   Heberg  Rev_par Bourse  presence
# 0         17/0001  interne    56879    Oui     0.695
# ...

# %%
table3.to_csv("dataset0.csv")

# %%
table3 =pd.read_csv("dataset0.csv")

# %%
table3.rename(columns={'presence': 'presenceP'}, inplace=True)

# %%
table3 = table3.assign(presence=0)
table3
# Out:
#         Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1 idRestaurant        date  \
# 0                0             0               0       Esi016  01-09-2019
# 1                1             1               1       Esi016  01-09-2019
# 2                2             2               2       Esi016  01-09-2019
# 3                3             3               3       Esi016  01-09-2019
# 4                4             4               4       Esi016  01-09-2019
# ...            ...           ...             ...          ...         ...
# 215995      215995        215995          215995       Esi016  15-08-2022
# 215996      215996        215996          215996       Esi016  15-08-2022
# 215997      215997        215997          215997       Esi016  15-08-2022
# 215998      215998        215998          215998       Esi016  15-08-2022
# 215999      215999        215999          215999       Esi016  15-08-2022
#
#         Type       Plat       meteo   Event idEtudiant   Heberg  Rev_par  \
# ...

# %%
table3=table3.drop(["presenceP.1"],axis=1)

# %%
table3
# Out:
#         Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1 idRestaurant        date  \
# 0                0             0               0       Esi016  01-09-2019
# 1                1             1               1       Esi016  01-09-2019
# 2                2             2               2       Esi016  01-09-2019
# 3                3             3               3       Esi016  01-09-2019
# 4                4             4               4       Esi016  01-09-2019
# ...            ...           ...             ...          ...         ...
# 215995      215995        215995          215995       Esi016  15-08-2022
# 215996      215996        215996          215996       Esi016  15-08-2022
# 215997      215997        215997          215997       Esi016  15-08-2022
# 215998      215998        215998          215998       Esi016  15-08-2022
# 215999      215999        215999          215999       Esi016  15-08-2022
#
#         Type       Plat       meteo   Event idEtudiant   Heberg  Rev_par  \
# ...

# %%
def decideA(presP):
    Type = [0,1]
    weight = [1.2-presP,presP]
    return choices(Type,weight)[0]

# %%
def decide(presP):
    if (presP>=0.6):
        return 1
    return 0

# %%
decide(0.798)
# Out:
# 1

# %%
table3
# Out:
#         Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1 idRestaurant        date  \
# 0                0             0               0       Esi016  01-09-2019
# 1                1             1               1       Esi016  01-09-2019
# 2                2             2               2       Esi016  01-09-2019
# 3                3             3               3       Esi016  01-09-2019
# 4                4             4               4       Esi016  01-09-2019
# ...            ...           ...             ...          ...         ...
# 215995      215995        215995          215995       Esi016  15-08-2022
# 215996      215996        215996          215996       Esi016  15-08-2022
# 215997      215997        215997          215997       Esi016  15-08-2022
# 215998      215998        215998          215998       Esi016  15-08-2022
# 215999      215999        215999          215999       Esi016  15-08-2022
#
#         Type       Plat       meteo   Event idEtudiant   Heberg  Rev_par  \
# ...

# %%
for i in range(216000):
    table3["presence"][i] = decide(table3["presenceP"][i])
# Out:
# <ipython-input-60-b2e2581f3c36>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   table3["presence"][i] = decide(table3["presenceP"][i])

# %%
table3
# Out:
#         Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1 idRestaurant        date  \
# 0                0             0               0       Esi016  01-09-2019
# 1                1             1               1       Esi016  01-09-2019
# 2                2             2               2       Esi016  01-09-2019
# 3                3             3               3       Esi016  01-09-2019
# 4                4             4               4       Esi016  01-09-2019
# ...            ...           ...             ...          ...         ...
# 215995      215995        215995          215995       Esi016  15-08-2022
# 215996      215996        215996          215996       Esi016  15-08-2022
# 215997      215997        215997          215997       Esi016  15-08-2022
# 215998      215998        215998          215998       Esi016  15-08-2022
# 215999      215999        215999          215999       Esi016  15-08-2022
#
#         Type       Plat       meteo   Event idEtudiant   Heberg  Rev_par  \
# ...

# %%
table3.to_csv("tablePredection3.csv")

# %%
f,ax = plt.subplots(1,1,figsize=(20,8))
plt1 = table3.groupby(['date'], as_index=False).agg({'presence': np.sum})
plt1=plt1.set_index('date')
plt1.plot(color='salmon', kind='area', ax=ax)
plt.ylabel("Total des présents")
plt.title("Répartitions des présents par date")
# Out:
# Text(0.5, 1.0, 'Répartitions des présents par date')

# %%
table4=table3.groupby(['date'],as_index=False).sum()

# %%
table4 = table4[['date','presence']].sort_values(by=['date'], 
ascending=True)

# %%
table4
# Out:
#             date  presence
# 0     01-01-2020         0
# 1     01-01-2021         0
# 2     01-01-2022         0
# 3     01-02-2020       105
# 4     01-02-2021       176
# ...          ...       ...
# 1075  31-10-2020        82
# 1076  31-10-2021       153
# 1077  31-12-2019       153
# 1078  31-12-2020       186
# 1079  31-12-2021         0
#
# [1080 rows x 2 columns]

# %%
nbpres = pd.read_excel("NbPresence.xlsx")
nbpres
# Out:
#            date  presence
# 0    2019-09-01       118
# 1    2019-09-02       137
# 2    2019-09-03       115
# 3    2019-09-04       110
# 4    2019-09-05       139
# ...         ...       ...
# 1075 2022-08-11       126
# 1076 2022-08-12         0
# 1077 2022-08-13       104
# 1078 2022-08-14       136
# 1079 2022-08-15       134
#
# [1080 rows x 2 columns]

# %%
f,ax = plt.subplots(1,1,figsize=(20,8))
plt1=pres.set_index('date')
plt1.plot(color='salmon', kind='area', ax=ax)
plt.ylabel("Total des présents")
plt.title("Répartitions des présents par date")
# Out:
# Text(0.5, 1.0, 'Répartitions des présents par date')

# %%
plt.figure(figsize=(15,7))
plt.plot(pres['date'][0:365], pres['presence'][0:365])
plt.title("Visitors")
plt.xlabel("date")
plt.ylabel("visitors")
plt.show()

# %%
for i in range(1080):
    pres['date'][i] = str(pres['date'][i])
# Out:
# <ipython-input-159-885ff2fb9179>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pres['date'][i] = str(pres['date'][i])

# %%
nbpres = pd.read_excel("datasetPFE.xlsx")
nbpres
# Out:
#             date  presence
# 0     01-09-2019       153
# 1     02-09-2019       153
# 2     03-09-2019       105
# 3     04-09-2019        82
# 4     05-09-2019       176
# ...          ...       ...
# 1075  11-08-2022       176
# 1076  12-08-2022         0
# 1077  13-08-2022        82
# 1078  14-08-2022       153
# 1079  15-08-2022       153
#
# [1080 rows x 2 columns]

# %%
resultfinal = pd.merge(resultf,presn, on="date")
resultfinal
# Out:
#      idRestaurant        date  Type       Plat       meteo    Event  presence
# 0          Esi016  01-09-2019  midi  Lentilles  Ensoleillé   Normal       153
# 1          Esi016  02-09-2019  midi     Loubia  Ensoleillé   Normal       153
# 2          Esi016  03-09-2019  midi        Riz  Ensoleillé   Normal       105
# 3          Esi016  04-09-2019  midi  Spaghetti  Ensoleillé   Normal        82
# 4          Esi016  05-09-2019  midi   Couscous  Ensoleillé   Normal       176
# ...           ...         ...   ...        ...         ...      ...       ...
# 1075       Esi016  11-08-2022  midi   Couscous  Ensoleillé   Normal       176
# 1076       Esi016  12-08-2022  midi    Weekend  Ensoleillé  Weekend         0
# 1077       Esi016  13-08-2022  midi    Weekend  Ensoleillé   Normal        82
# 1078       Esi016  14-08-2022  midi  Lentilles  Ensoleillé   Normal       153
# 1079       Esi016  15-08-2022  midi     Loubia  Ensoleillé   Normal       153
#
# [1080 rows x 7 columns]

# %%
table3["Plat"].replace(["Lentilles","Loubia","Riz","Spaghetti","Couscous","Weekend"],[0,1,2,3,4,5],inplace=True)
table3["meteo"].replace(["Ensoleillé","Nuageux","Mauvais"],[0,1,2],inplace=True)
table3["Event"].replace(["Normal","Weekend","Jour férié","Ramadan"],[0,1,2,3],inplace=True)
table3["Heberg"].replace(["interne","externe"],[0,1],inplace=True)
table3["Bourse"].replace(["Oui","Non"],[0,1],inplace=True)

# %%
fig, axes = plt.subplots(figsize= (10,8))
sns.heatmap(table3.corr(), annot=True, cmap='Oranges')
plt.xticks(rotation=30, ha='right')
plt.title("Matrice de corrélation")
plt.show()

# %%
table3
# Out:
#         Unnamed: 0 idRestaurant        date  Type  Plat  meteo  Event  \
# 0                0       Esi016  01-09-2019  midi     0      0      0
# 1                1       Esi016  01-09-2019  midi     0      0      0
# 2                2       Esi016  01-09-2019  midi     0      0      0
# 3                3       Esi016  01-09-2019  midi     0      0      0
# 4                4       Esi016  01-09-2019  midi     0      0      0
# ...            ...          ...         ...   ...   ...    ...    ...
# 215995      215995       Esi016  15-08-2022  midi     1      0      0
# 215996      215996       Esi016  15-08-2022  midi     1      0      0
# 215997      215997       Esi016  15-08-2022  midi     1      0      0
# 215998      215998       Esi016  15-08-2022  midi     1      0      0
# 215999      215999       Esi016  15-08-2022  midi     1      0      0
#
#        idEtudiant  Heberg  Rev_par  Bourse  presenceP  presence
# ...

# %% [markdown]
# # Construction de jeu de données

# %%
training_data = table3.sample(frac=2/3, random_state=0)
testing_data = table3.drop(training_data.index)

# %%
training_data.size
# Out:
# 1728000

# %%
testing_data.size
# Out:
# 864000

# %%
training_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-88-aa4368bc1598> in <module>
# ----> 1 training_data
#
# NameError: name 'training_data' is not defined

# %%
x=table3.drop(["idRestaurant","Type","idEtudiant","presenceP","presence","Unnamed: 0","meteo","Bourse"] , axis=1)   
y=table3["presence"]

# %%
x
# Out:
#               date  Plat  Event  Heberg  Rev_par
# 0       01-09-2019     0      0       0    56879
# 1       01-09-2019     0      0       1    19184
# 2       01-09-2019     0      0       1    56879
# 3       01-09-2019     0      0       1    19184
# 4       01-09-2019     0      0       0   139936
# ...            ...   ...    ...     ...      ...
# 215995  15-08-2022     1      0       0    25251
# 215996  15-08-2022     1      0       0    19184
# 215997  15-08-2022     1      0       0    56879
# 215998  15-08-2022     1      0       0    56879
# 215999  15-08-2022     1      0       1    46901
#
# [216000 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=1/3,random_state=None,shuffle = False)

# %%
X_train=X_train.drop(["date"],axis=1)

# %%
X_train
# Out:
#         Plat  Event  Heberg  Rev_par
# 0          0      0       0    56879
# 1          0      0       1    19184
# 2          0      0       1    56879
# 3          0      0       1    19184
# 4          0      0       0   139936
# ...      ...    ...     ...      ...
# 143995     5      1       0    25251
# 143996     5      1       0    19184
# 143997     5      1       0    56879
# 143998     5      1       0    56879
# 143999     5      1       1    46901
#
# [144000 rows x 4 columns]

# %%
X_test.drop(["date"],axis=1)
# Out:
#         Plat  Event  Heberg  Rev_par
# 144000     5      0       0    56879
# 144001     5      0       1    19184
# 144002     5      0       1    56879
# 144003     5      0       1    19184
# 144004     5      0       0   139936
# ...      ...    ...     ...      ...
# 215995     1      0       0    25251
# 215996     1      0       0    19184
# 215997     1      0       0    56879
# 215998     1      0       0    56879
# 215999     1      0       1    46901
#
# [72000 rows x 4 columns]

# %%
 from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
print('Score du model =', model.score(X_train,y_train ))
# Out:
# Score du model = 0.4676458333333333

# %%
cm = confusion_matrix(model.predict(X_train),y_train)
print(cm)
# Out:
# [[49846  6334]
#  [17495 70325]]

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model=KNeighborsClassifier(10)

# %%
model.fit(X_train,y_train )
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
print('Coeff R2 =', model.score(X_train,y_train ))
# Out:
# Coeff R2 = 1.0

# %%
cm = confusion_matrix(model.predict(X_train),y_train)
print(cm)
# Out:
# [[70883     0]
#  [    0 80317]]

# %%
tableMod = pd.read_csv("tablePredection.csv")

# %%
tableMod=tableMod.drop(["Unnamed: 0","Unnamed: 0.1"],axis=1)

# %%
tableMod
# Out:
#        idRestaurant        date  Type       Plat       meteo   Event  \
# 0            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 1            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 2            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 3            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# 4            Esi016  01-09-2019  midi  Lentilles  Ensoleillé  Normal
# ...             ...         ...   ...        ...         ...     ...
# 215995       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215996       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215997       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215998       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
# 215999       Esi016  15-08-2022  midi     Loubia  Ensoleillé  Normal
#
#        idEtudiant   Heberg  Rev_par Bourse  presenceP  presence
# 0         17/0001  interne    56879    Oui      0.525         0
# ...

# %%
for i in range(216000):
    tableMod["presence"][i] = decide(tableMod["presenceP"][i])
# Out:
# <ipython-input-120-49da3f113eed>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tableMod["presence"][i] = decide(tableMod["presenceP"][i])

# %%
tableMod.to_csv("StudentRest.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-6ecef60af0a2> in <module>
# ----> 1 tableMod.to_csv("StudentRest.csv")
#
# NameError: name 'tableMod' is not defined

# %%
tableSum=tableMod.groupby(['date'],as_index=False).sum()
tableSum=tableSum.drop(['Rev_par','presenceP'], axis=1)

# %%
tableSum
# Out:
#             date  presence
# 0     01-01-2020         0
# 1     01-01-2021         0
# 2     01-01-2022         0
# 3     01-02-2020       119
# 4     01-02-2021       135
# ...          ...       ...
# 1075  31-10-2020       118
# 1076  31-10-2021       133
# 1077  31-12-2019       128
# 1078  31-12-2020       151
# 1079  31-12-2021         0
#
# [1080 rows x 2 columns]

# %%
tableSum.to_excel("NbPresence.xlsx")

# %%
nbpres = pd.read_excel("NbPresence.xlsx")
nbpres
# Out:
#            date  presence    Event
# 0    2019-09-01       118   Normal
# 1    2019-09-02       137   Normal
# 2    2019-09-03       115   Normal
# 3    2019-09-04       110   Normal
# 4    2019-09-05       139   Normal
# ...         ...       ...      ...
# 1075 2022-08-11       126   Normal
# 1076 2022-08-12         0  Weekend
# 1077 2022-08-13       104   Normal
# 1078 2022-08-14       136   Normal
# 1079 2022-08-15       134   Normal
#
# [1080 rows x 3 columns]

# %%
f,ax = plt.subplots(1,1,figsize=(20,8))
plt1=nbpres.set_index('date')
plt1.plot(color='salmon', kind='area', ax=ax)
plt.ylabel("Total des présents")
plt.title("Répartitions des présents par date")
# Out:
# Text(0.5, 1.0, 'Répartitions des présents par date')

# %% [markdown]
# # Time series

# %%
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA
from matplotlib.pylab import rcParams

# %%
indexedDataset
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-d0f86f8ee308> in <module>
# ----> 1 indexedDataset
#
# NameError: name 'indexedDataset' is not defined

# %%
indexedDataset=indexedDataset.drop(columns=['Event'], axis=1)

# %%
indexedDataset
# Out:
#             presence
# date
# 2019-09-01       118
# 2019-09-02       137
# 2019-09-03       115
# 2019-09-04       110
# 2019-09-05       139
# ...              ...
# 2022-08-10       116
# 2022-08-11       126
# 2022-08-13       104
# 2022-08-14       136
# 2022-08-15       134
#
# [818 rows x 1 columns]

# %%
nbpres.drop(nbpres[nbpres.presence==0].index, inplace=True)
nbpres['date'] = pd.to_datetime(nbpres['date'],infer_datetime_format=True) #convert from string to datetime
indexedDataset = nbpres.set_index(['date'])

# %%
plt.xlabel('Date')
plt.ylabel("nombre d'étudiants présents")
plt.plot(indexedDataset.presence)

# %%
rolmean = indexedDataset.rolling(window=7).mean() #window size 12 denotes 12 months, giving rolling mean at yearly level
rolstd = indexedDataset.rolling(window=7).std()
print(rolmean,rolstd)
# Out:
#               presence
# date
# 2019-09-01         NaN
# 2019-09-02         NaN
# 2019-09-03         NaN
# 2019-09-04         NaN
# 2019-09-05         NaN
# ...                ...
# 2022-08-10  122.142857
# 2022-08-11  122.000000
# 2022-08-13  118.285714
# 2022-08-14  117.000000
# 2022-08-15  120.142857
#
# [818 rows x 1 columns]              presence
# date
# 2019-09-01        NaN
# 2019-09-02        NaN
# 2019-09-03        NaN
# 2019-09-04        NaN
# 2019-09-05        NaN
# ...               ...
# 2022-08-10  12.641579
# 2022-08-11  12.583057
# 2022-08-13  13.622460
# 2022-08-14  10.816654
# 2022-08-15  12.226046
#
# [818 rows x 1 columns]

# %%
#Plot rolling statistics
plt.figure(figsize=(15,7))
orig = plt.plot(indexedDataset.presence, color='blue', label='Original')
mean = plt.plot(rolmean, color='red', label='Rolling Mean')
std = plt.plot(rolstd, color='black', label='Rolling Std')
plt.legend(loc='best')
plt.title('Rolling Mean & Standard Deviation')
plt.show(block=False)

# %%
print('Results of Dickey Fuller Test:')
dftest = adfuller(indexedDataset['presence'], autolag='AIC')

dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
    
print(dfoutput)
# Out:
# Results of Dickey Fuller Test:
# Test Statistic                  -3.310459
# p-value                          0.014417
# #Lags Used                      11.000000
# Number of Observations Used    806.000000
# Critical Value (1%)             -3.438489
# Critical Value (5%)             -2.865133
# Critical Value (10%)            -2.568683
# dtype: float64

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plt.rcParams.update({'figure.figsize':(9,7), 'figure.dpi':120})


# Original Series
fig, axes = plt.subplots(3, 2, sharex=False)
axes[0, 0].plot(indexedDataset.presence); axes[0, 0].set_title('Original Series')
plot_acf(indexedDataset.presence, ax=axes[0, 1])

# 1st Differencing
axes[1, 0].plot(indexedDataset.presence.diff()); axes[1, 0].set_title('1st Order Differencing')
plot_acf(indexedDataset.presence.diff().dropna(), ax=axes[1, 1])

# 2nd Differencing
axes[2, 0].plot(indexedDataset.presence.diff().diff()); axes[2, 0].set_title('2nd Order Differencing')
plot_acf(indexedDataset.presence.diff().diff().dropna(), ax=axes[2, 1])

plt.show()

# %%
# PACF plot of 1st differenced series
plt.rcParams.update({'figure.figsize':(9,3), 'figure.dpi':120})

fig, axes = plt.subplots(1, 2, sharex=False)
axes[0].plot(indexedDataset.presence); axes[0].set_title('no Differencing')
#axes[1].set(ylim=(-1,1))
plot_pacf(indexedDataset.presence.dropna(), ax=axes[1])

plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plt.rcParams.update({'figure.figsize':(9,3), 'figure.dpi':120})

fig, axes = plt.subplots(1, 2, sharex=False)
axes[0].plot(indexedDataset.presence); axes[0].set_title('no Differencing')
plot_acf(indexedDataset.presence.dropna(), ax=axes[1])

plt.show()

# %%
from statsmodels.tsa.arima_model import ARIMA

# 1,0,2 ARIMA Model
model = ARIMA(indexedDataset.presence, order=(1,0,2))
model_fit = model.fit(disp=0)
print(model_fit.summary())
# Out:
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# ...

# %%
# 1,1,1 ARIMA Model
model = ARIMA(indexedDataset.presence, order=(1,0,1))
model_fit = model.fit(disp=0)
print(model_fit.summary())
# Out:
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# ...

# %%
residuals = pd.DataFrame(model_fit.resid)
fig, ax = plt.subplots(1,2)
residuals.plot(title="Residuals", ax=ax[0])
residuals.plot(kind='kde', title='Density', ax=ax[1])
plt.show()

# %%
model_fit.plot_predict(dynamic=False)
plt.show()

# %%
model_fit.predict()
# Out:
# date
# 2019-09-01    128.266419
# 2019-09-02    130.659221
# 2019-09-03    126.169511
# 2019-09-04    131.402437
# 2019-09-05    132.391692
#                  ...
# 2022-08-10    132.636546
# 2022-08-11    130.964224
# 2022-08-13    128.704409
# 2022-08-14    133.865990
# 2022-08-15    126.298268
# Length: 818, dtype: float64

# %%
train = indexedDataset.presence[:497]
test = indexedDataset.presence[497:]

# %%
indexedDataset
# Out:
#             presence
# date
# 2019-09-01       118
# 2019-09-02       137
# 2019-09-03       115
# 2019-09-04       110
# 2019-09-05       139
# ...              ...
# 2022-08-10       116
# 2022-08-11       126
# 2022-08-13       104
# 2022-08-14       136
# 2022-08-15       134
#
# [818 rows x 1 columns]

# %%
model = ARIMA(train, order=(1, 0, 1))  
fitted = model.fit(disp=-1)  
print(fitted.summary())

# Forecast
fc, se, conf = fitted.forecast(321,alpha=0.05)  # 95% conf

# Make as pandas series
fc_series = pd.Series(fc, index=test.index)
lower_series = pd.Series(conf[:, 0], index=test.index)
upper_series = pd.Series(conf[:, 1], index=test.index)

# Plot
plt.figure(figsize=(12,5), dpi=100)
plt.plot(train, label='training')
plt.plot(test, label='actual')
plt.plot(fc_series, label='forecast')
plt.fill_between(lower_series.index, lower_series, upper_series, 
                 color='k', alpha=.15)
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)
plt.show()
# Out:
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# ...

# %%
model = ARIMA(train, order=(3, 0, 1))  
fitted = model.fit(disp=-1)  
print(fitted.summary())

# Forecast
fc, se, conf = fitted.forecast(321, alpha=0.05)  # 95% conf

# Make as pandas series
fc_series = pd.Series(fc, index=test.index)
lower_series = pd.Series(conf[:, 0], index=test.index)
upper_series = pd.Series(conf[:, 1], index=test.index)

# Plot
plt.figure(figsize=(12,5), dpi=100)
plt.plot(train, label='training')
plt.plot(test, label='actual')
plt.plot(fc_series, label='forecast')
plt.fill_between(lower_series.index, lower_series, upper_series, 
                 color='k', alpha=.15)
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)
plt.show()
# Out:
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# ...

# %%
def forecast_accuracy(forecast, actual):
    mape = np.mean(np.abs(forecast - actual)/np.abs(actual))  # MAPE
    me = np.mean(forecast - actual)             # ME
    mae = np.mean(np.abs(forecast - actual))    # MAE
    mpe = np.mean((forecast - actual)/actual)   # MPE
    rmse = np.mean((forecast - actual)**2)**.5  # RMSE
    corr = np.corrcoef(forecast, actual)[0,1]   # corr
    mins = np.amin(np.hstack([forecast[:,None], 
                              actual[:,None]]), axis=1)
    maxs = np.amax(np.hstack([forecast[:,None], 
                              actual[:,None]]), axis=1)
    minmax = 1 - np.mean(mins/maxs)             # minmax
    acf1 = acf(fc-test)[1]                      # ACF1
    return({'mape':mape, 'me':me, 'mae': mae, 
            'mpe': mpe, 'rmse':rmse, 'acf1':acf1, 
            'corr':corr, 'minmax':minmax})

forecast_accuracy(fc, test.values)
# Out:
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:657: FutureWarning: The default number of lags is changing from 40 tomin(int(10 * np.log10(nobs)), nobs - 1) after 0.12is released. Set the number of lags to an integer to  silence this warning.
#   warnings.warn(
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:667: FutureWarning: fft=True will become the default after the release of the 0.12 release of statsmodels. To suppress this warning, explicitly set fft=False.
#   warnings.warn(
# {'mape': 0.09205890642065101,
#  'me': 1.0874062735357226,
#  'mae': 11.309355759242104,
#  'mpe': 0.0213319014712863,
#  'rmse': 14.07612198591551,
#  'acf1': -0.20715323790316592,
#  'corr': 0.09422446398193085,
#  'minmax': 0.08363731401990271}

# %%
# !pip install pmdarima

# %%
from statsmodels.tsa.arima_model import ARIMA

import pmdarima as pm

model = pm.auto_arima(indexedDataset.presence, start_p=1, start_q=1,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=15, max_q=6, # maximum p and q
                      m=1,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=1,
                      start_Q=1,
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)

print(model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=6617.594, Time=0.50 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=10274.490, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=7388.613, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=9446.656, Time=0.15 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=6491.138, Time=0.81 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=inf, Time=0.08 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=6439.536, Time=0.59 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=inf, Time=0.17 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=6425.754, Time=0.73 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=inf, Time=0.81 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=6425.233, Time=1.59 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=inf, Time=0.35 sec
#  ARIMA(6,0,1)(0,0,0)[0]             : AIC=6326.036, Time=3.66 sec
#  ARIMA(6,0,0)(0,0,0)[0]             : AIC=inf, Time=1.01 sec
# ...

# %%
model = ARIMA(train, order=(6,0,2))  
fitted = model.fit(disp=-1)  
print(fitted.summary())

# Forecast
fc, se, conf = fitted.forecast(321, alpha=0.05)  # 95% conf

# Make as pandas series
fc_series = pd.Series(fc, index=test.index)
lower_series = pd.Series(conf[:, 0], index=test.index)
upper_series = pd.Series(conf[:, 1], index=test.index)

# Plot
plt.figure(figsize=(12,5), dpi=100)
plt.plot(train, label='training')
plt.plot(test, label='actual')
plt.plot(fc_series, label='forecast')
plt.fill_between(lower_series.index, lower_series, upper_series, 
                 color='k', alpha=.15)
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)
plt.show()
# Out:
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# ...

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
arima_model = SARIMAX(train, order = (6,0,2), seasonal_order = (1,0,1,12))
arima_result = arima_model.fit()
arima_result.summary()
# Out:
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ...

# %%
model = ARIMA(train, order=(6, 0, 2))  
fitted = model.fit(disp=-1)  
print(fitted.summary())

# Forecast
fc, se, conf = fitted.forecast(321, alpha=0.05)  # 95% conf

# Make as pandas series
fc_series = pd.Series(fc, index=test.index)
lower_series = pd.Series(conf[:, 0], index=test.index)
upper_series = pd.Series(conf[:, 1], index=test.index)

# Plot
plt.figure(figsize=(12,5), dpi=100)
plt.plot(train, label='training')
plt.plot(test, label='actual')
plt.plot(fc_series, label='forecast')
plt.fill_between(lower_series.index, lower_series, upper_series, 
                 color='k', alpha=.15)
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)
plt.show()
# Out:
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# ...

# %%
arima_pred = arima_result.predict(start = len(train), end = len(indexedDataset)-1, typ="levels").rename("ARIMA Predictions")
arima_pred
# Out:
# C:\Users\Laghoub\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:376: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   warnings.warn('No supported index is available.'
# 497    127.763916
# 498    135.200067
# 499    117.378222
# 500    129.186563
# 501    136.832447
#           ...
# 813    129.992872
# 814    124.118039
# 815    128.679442
# 816    129.852128
# 817    125.172928
# Name: ARIMA Predictions, Length: 321, dtype: float64

# %%
listArima =[]
for i in arima_pred:
    listArima.append(i)

# %%
listArima
# Out:
# [127.76391599651298,
#  135.20006656494132,
#  117.37822209298135,
#  129.18656329691038,
#  136.83244664837287,
#  116.61487317131169,
#  130.45781334114682,
#  131.00665268679936,
#  122.85532304906981,
#  126.34723591778187,
#  133.38012127755655,
#  119.35864290808743,
#  129.84769615275027,
#  128.12495834753446,
#  123.8672977269633,
#  129.58202788863593,
#  131.60329267931343,
#  121.24733891372003,
#  129.84964682885118,
#  128.45121662528624,
#  125.34204452828651,
#  126.31903641361006,
#  131.39107676724078,
#  121.47022817655353,
#  129.2342006149327,
#  127.44088525955613,
#  124.74692868519271,
#  129.5960450145707,
#  130.77351182934706,
#  122.2651814251289,
#  129.3870951864939,
#  128.40233002233538,
#  125.5677063066056,
#  126.4294983822082,
#  130.97904819278318,
#  122.02579650346756,
#  128.90164330753367,
#  127.59288298086385,
#  124.72360542976418,
#  129.7565587178218,
#  130.516869932974,
#  122.62086204842568,
#  129.1386720436534,
# ...

# %%
test.plot(figsize = (16,5), legend=True)
arima_pred.plot(figsize = (16,5), legend=True)
# Out:
# <AxesSubplot:xlabel='date'>

# %%
prevision = {
  "Test": test,
  "Arima Result": listArima,
}
timeSeriesPrev = pd.DataFrame(prevision)

# %%
timeSeriesPrev
# Out:
#             Test  Arima Result
# date
# 2021-06-20   132    127.763916
# 2021-06-21   124    135.200067
# 2021-06-22   120    117.378222
# 2021-06-23   128    129.186563
# 2021-06-24   148    136.832447
# ...          ...           ...
# 2022-08-10   116    129.992872
# 2022-08-11   126    124.118039
# 2022-08-13   104    128.679442
# 2022-08-14   136    129.852128
# 2022-08-15   134    125.172928
#
# [321 rows x 2 columns]

# %%
timeSeriesPrev.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
from sklearn.metrics import mean_squared_error
from statsmodels.tools.eval_measures import rmse
arima_rmse_error = rmse(test, arima_pred)
arima_mse_error = arima_rmse_error**2
mean_value = indexedDataset.presence.mean()

print(f'MSE Error: {arima_mse_error}\nRMSE Error: {arima_rmse_error}\nMean: {mean_value}')
# Out:
# MSE Error: 3172.3327676288695
# RMSE Error: 56.323465515084116
# Mean: 638.3677852348993

# %% [markdown]
# # LSTM

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
train = train.values.reshape(-1,1)

# %%
test = test.values.reshape(-1,1)

# %%
scaler.fit(train)
scaled_train_data = scaler.transform(train)
scaled_test_data = scaler.transform(test)

# %%
from keras.preprocessing.sequence import TimeseriesGenerator

n_input = 12
n_features= 1
generator = TimeseriesGenerator(scaled_train_data, scaled_train_data, length=n_input, batch_size=1)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

lstm_model = Sequential()
lstm_model.add(LSTM(200, activation='relu', input_shape=(n_input, n_features)))
lstm_model.add(Dense(1))
lstm_model.compile(optimizer='adam', loss='mse')

lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm (LSTM)                  (None, 200)               161600
# _________________________________________________________________
# dense (Dense)                (None, 1)                 201
# ...
# Total params: 161,801
# Trainable params: 161,801
# Non-trainable params: 0
# _________________________________________________________________

# %%
lstm_model.fit_generator(generator,epochs=12)
# Out:
# C:\Users\Laghoub\anaconda3\lib\site-packages\keras\engine\training.py:1915: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/12
# 708/708 [==============================] - 42s 11ms/step - loss: 0.1336
# Epoch 2/12
# 708/708 [==============================] - 7s 10ms/step - loss: 0.1119
# Epoch 3/12
# 708/708 [==============================] - 7s 10ms/step - loss: 0.0874
# Epoch 4/12
# 708/708 [==============================] - 7s 10ms/step - loss: 0.0773
# Epoch 5/12
# 708/708 [==============================] - 7s 10ms/step - loss: 0.0639
# Epoch 6/12
# 708/708 [==============================] - 7s 10ms/step - loss: 0.0611
# Epoch 7/12
# 708/708 [==============================] - 7s 10ms/step - loss: 0.0419
# Epoch 8/12
# 708/708 [==============================] - 7s 10ms/step - loss: 0.0370
# Epoch 9/12
# ...

# %%
losses_lstm = lstm_model.history.history['loss']
plt.figure(figsize=(12,4))
plt.xticks(np.arange(0,21,1))
plt.plot(range(len(losses_lstm)),losses_lstm);

# %%
lstm_predictions_scaled = list()

batch = scaled_train_data[-n_input:]
current_batch = batch.reshape((1, n_input, n_features))

for i in range(len(test)):   
    lstm_pred = lstm_model.predict(current_batch)[0]
    lstm_predictions_scaled.append(lstm_pred) 
    current_batch = np.append(current_batch[:,1:,:],[[lstm_pred]],axis=1)

# %%
lstm_predictions_scaled
# Out:
# [array([0.55899465], dtype=float32),
#  array([0.60337996], dtype=float32),
#  array([0.6579571], dtype=float32),
#  array([0.6885567], dtype=float32),
#  array([0.7098489], dtype=float32),
#  array([0.4771264], dtype=float32),
#  array([0.22951356], dtype=float32),
#  array([0.5448853], dtype=float32),
#  array([0.6419748], dtype=float32),
#  array([0.6287861], dtype=float32),
#  array([0.65216756], dtype=float32),
#  array([0.6947688], dtype=float32),
#  array([0.55573624], dtype=float32),
#  array([0.08513632], dtype=float32),
#  array([0.49243852], dtype=float32),
#  array([0.6509675], dtype=float32),
#  array([0.6847061], dtype=float32),
#  array([0.711483], dtype=float32),
#  array([0.75192595], dtype=float32),
#  array([0.6545564], dtype=float32),
#  array([0.01058975], dtype=float32),
#  array([0.5749737], dtype=float32),
#  array([0.70021033], dtype=float32),
#  array([0.73933387], dtype=float32),
#  array([0.7525761], dtype=float32),
#  array([0.79321885], dtype=float32),
# ...

# %%
lstm_predictions = scaler.inverse_transform(lstm_predictions_scaled)

# %%
lstm_predictions
# Out:
# array([[ 93.35210669],
#        [100.76445413],
#        [109.87883186],
#        [114.98896408],
#        [118.54476309],
#        [ 79.68010709],
#        [ 38.32876381],
#        [ 90.99584138],
#        [107.20979273],
#        [105.00727654],
#        [108.9119823 ],
#        [116.02638733],
#        [ 92.8079527 ],
#        [ 14.21776614],
#        [ 82.23723367],
#        [108.71156895],
#        [114.34591734],
#        [118.81766129],
#        [125.57163286],
#        [109.31091774],
#        [  1.76848802],
#        [ 96.02060831],
#        [116.93512559],
#        [123.46875596],
#        [125.68021083],
#        [132.46754813],
#        [127.59364367],
#        [ -7.51821294],
#        [109.62639904],
#        [123.51922262],
#        [130.28995669],
#        [131.07411098],
#        [138.77956319],
#        [136.35425711],
#        [ -3.23889428],
#        [113.38872313],
#        [124.94371617],
#        [132.11609316],
#        [132.38751817],
#        [140.26087403],
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-453dcda9cfc1> in <module>
# ----> 1 listLSTM2.plot(legend = True);
#
# AttributeError: 'list' object has no attribute 'plot'

# %%
listLSTM = lstm_predictions.tolist()

# %%
listLSTM2 = []
for i in listLSTM:
    listLSTM2.append(i[0])

# %%
listLSTM2
# Out:
# [93.3521066904068,
#  100.76445412635803,
#  109.87883186340332,
#  114.98896408081055,
#  118.5447630882263,
#  79.6801070868969,
#  38.32876381278038,
#  90.99584138393402,
#  107.20979273319244,
#  105.00727653503418,
#  108.91198229789734,
#  116.02638733386993,
#  92.80795270204544,
#  14.217766135931015,
#  82.23723366856575,
#  108.71156895160675,
#  114.34591734409332,
#  118.81766128540038,
#  125.57163286209105,
#  109.31091773509979,
#  1.7684880197048187,
#  96.02060830593109,
#  116.93512558937073,
#  123.46875596046446,
#  125.68021082878111,
#  132.46754813194275,
#  127.5936436653137,
#  -7.518212944269179,
#  109.62639904022217,
#  123.51922261714934,
#  130.28995668888092,
#  131.07411098480225,
#  138.77956318855286,
#  136.354257106781,
#  -3.238894283771515,
#  113.3887231349945,
#  124.94371616840361,
#  132.11609315872192,
#  132.38751816749573,
#  140.26087403297424,
#  137.661074757576,
#  -2.7384208291769028,
#  112.18425226211548,
#  124.74871778488158,
# ...

# %%
prevision = {
  "Test": listTest,
  "Arima Result": listArima,
  "Lstm Result" : listLSTM2,
}
timeSeriesPrev = pd.DataFrame(prevision)

# %%
listTest = []
for i in test:
    listTest.append(i[0])

# %%
timeSeriesPrev.to_excel("ResultTimeSeriesPrev2.xlsx")

# %%
timeSeriesPrev
# Out:
#      Test  Arima Result  Lstm Result
# 0      98    104.527526    93.352107
# 1     117    124.997783   100.764454
# 2     127     76.712617   109.878832
# 3     118     90.530259   114.988964
# 4     116     78.106932   118.544763
# ..    ...           ...          ...
# 355   126    117.230540   138.441745
# 356     0     55.329335    -1.609725
# 357   104    108.188191   112.748802
# 358   136     75.989113   124.521349
# 359   134     75.214630   132.537505
#
# [360 rows x 3 columns]

# %%
timeSeriesPrev.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Classification

# %%
classf = pd.read_csv("StudentRest.csv")
classf
# Out:
#         Unnamed: 0 idRestaurant        date  Type       Plat       meteo  \
# 0                0       Esi016  01-09-2019  midi  Lentilles  Ensoleillé
# 1                1       Esi016  01-09-2019  midi  Lentilles  Ensoleillé
# 2                2       Esi016  01-09-2019  midi  Lentilles  Ensoleillé
# 3                3       Esi016  01-09-2019  midi  Lentilles  Ensoleillé
# 4                4       Esi016  01-09-2019  midi  Lentilles  Ensoleillé
# ...            ...          ...         ...   ...        ...         ...
# 215995      215995       Esi016  15-08-2022  midi     Loubia  Ensoleillé
# 215996      215996       Esi016  15-08-2022  midi     Loubia  Ensoleillé
# 215997      215997       Esi016  15-08-2022  midi     Loubia  Ensoleillé
# 215998      215998       Esi016  15-08-2022  midi     Loubia  Ensoleillé
# 215999      215999       Esi016  15-08-2022  midi     Loubia  Ensoleillé
#
#          Event idEtudiant   Heberg  Rev_par Bourse  presenceP  presence
# ...

# %%
classf = classf.drop(["Unnamed: 0","idRestaurant", "date", "Type" , "idEtudiant", "presenceP",  ],axis=1)

# %%
classf["Plat"].replace(["Lentilles","Loubia","Riz","Spaghetti","Couscous","Weekend"],[0,1,2,3,4,5],inplace=True)
classf["meteo"].replace(["Ensoleillé","Nuageux","Mauvais"],[0,1,2],inplace=True)
classf["Event"].replace(["Normal","Weekend","Jour férié","Ramadan"],[0,1,2,3],inplace=True)
classf["Heberg"].replace(["interne","externe"],[0,1],inplace=True)
classf["Bourse"].replace(["Oui","Non"],[0,1],inplace=True)

# %%
trainC = classf[:144000]
testC = classf[144000:]

# %%
trainC
# Out:
#         Plat  meteo  Event  Heberg  Rev_par  Bourse  presence
# 0          0      0      0       0    56879       0         0
# 1          0      0      0       1    19184       0         1
# 2          0      0      0       1    56879       0         0
# 3          0      0      0       1    19184       0         1
# 4          0      0      0       0   139936       1         1
# ...      ...    ...    ...     ...      ...     ...       ...
# 143995     5      0      1       0    25251       0         0
# 143996     5      0      1       0    19184       0         0
# 143997     5      0      1       0    56879       0         0
# 143998     5      0      1       0    56879       0         0
# 143999     5      0      1       1    46901       0         0
#
# [144000 rows x 7 columns]

# %%
fig, axes = plt.subplots(figsize= (10,8))
sns.heatmap(trainC.corr(), annot=True, cmap='Oranges')
plt.xticks(rotation=30, ha='right')
plt.title("Matrice de corrélation")
plt.show()

# %%
 from sklearn.linear_model import LogisticRegression

# %%
trainCY = trainC["presence"]

# %%
trainCX = trainC.drop(["presence"], axis =1)

# %%
testCY = testC["presence"]
testCX = testC.drop(["presence"], axis =1)

# %%
model = LogisticRegression()
model.fit(trainCX,trainCY)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e2e745668342> in <module>
# ----> 1 model = LogisticRegression()
#       2 model.fit(trainCX,trainCY)
#
# NameError: name 'LogisticRegression' is not defined

# %%
print('Score du modele =', model.score(trainCX,trainCY))
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-223-6b6ad20b5fdc> in <module>
# ----> 1 print('Score du modele =', model.score(trainCX,trainCY))
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     498         """
#     499         from .metrics import accuracy_score
# --> 500         return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#     501
#     502     def _more_tags(self):
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     307             Predicted class label per sample.
#     308         """
# --> 309         scores = self.decision_function(X)
#     310         if len(scores.shape) == 1:
#     311             indices = (scores > 0).astype(int)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in decision_function(self, X)
# ...

# %%
cm = confusion_matrix(model.predict(trainCX),trainCY)
print(cm)
#sns.heatmap(cm, annot=True)
# Out:
# [[74112 69888]
#  [    0     0]]

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
modelKnn = KNeighborsClassifier()

# %%
modelKnn.fit(trainCX,trainCY)
# Out:
# KNeighborsClassifier()

# %%
print('Score du modele =', modelKnn.score(trainCX,trainCY))
# Out:
# Score du modele = 0.6824375

# %%
cm = confusion_matrix(modelKnn.predict(trainCX),trainCY)
print(cm)
sns.heatmap(cm, annot=True)
# Out:
# [[45796 12994]
#  [28316 56894]]
# <AxesSubplot:>

# %%
previsiontimeSeries = {
  "presence" : result.LstmResult,
      "date": dataev[720:].date,
}
timeSeriesprevision = pd.DataFrame(previsiontimeSeries)

# %%
timeSeriesprevision
# Out:
#         presence        date
# 0      93.352107         NaN
# 1     100.764454         NaN
# 2     109.878832         NaN
# 3     114.988964         NaN
# 4     118.544763         NaN
# ...          ...         ...
# 1075         NaN  2022-08-11
# 1076         NaN  2022-08-12
# 1077         NaN  2022-08-13
# 1078         NaN  2022-08-14
# 1079         NaN  2022-08-15
#
# [720 rows x 2 columns]

# %%
# Out:
#             date    presence
# 0            NaN   93.352107
# 1            NaN  100.764454
# 2            NaN  109.878832
# 3            NaN  114.988964
# 4            NaN  118.544763
# ...          ...         ...
# 1075  2022-08-11         NaN
# 1076  2022-08-12         NaN
# 1077  2022-08-13         NaN
# 1078  2022-08-14         NaN
# 1079  2022-08-15         NaN
#
# [720 rows x 2 columns]

# %%
dataev = pd.read_csv('pres.csv')

# %%
dataev[720:].date
# Out:
# 720     2021-08-21
# 721     2021-08-22
# 722     2021-08-23
# 723     2021-08-24
# 724     2021-08-25
#            ...
# 1075    2022-08-11
# 1076    2022-08-12
# 1077    2022-08-13
# 1078    2022-08-14
# 1079    2022-08-15
# Name: date, Length: 360, dtype: object

# %%
result = pd.read_excel('ResultTimeSeriesPrev2.xlsx')
lstm= result.LstmResult

# %%
lstm.to_excel("lstm.xlsx")

# %%
date = dataev[720:].date
date
# Out:
# 720     2021-08-21
# 721     2021-08-22
# 722     2021-08-23
# 723     2021-08-24
# 724     2021-08-25
#            ...
# 1075    2022-08-11
# 1076    2022-08-12
# 1077    2022-08-13
# 1078    2022-08-14
# 1079    2022-08-15
# Name: date, Length: 360, dtype: object

# %%
date.to_excel('date.xlsx')
